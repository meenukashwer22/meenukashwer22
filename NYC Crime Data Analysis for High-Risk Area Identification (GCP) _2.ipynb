# %% [markdown]
# <a href="https://colab.research.google.com/github/meenukashwer22/meenukashwer22/blob/main/NYC%20Crime%20Data%20Analysis%20for%20High-Risk%20Area%20Identification%20(GCP)%20_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-cloud-bigquery

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import auth
auth.authenticate_user()

from google.cloud import bigquery
import pandas as pd

client = bigquery.Client(project="booming-octane-374400")  # Your project ID

# %%
# Authenticate Colab to access GCP
from google.colab import auth
auth.authenticate_user()

# Import BigQuery client
from google.cloud import bigquery
import pandas as pd

# Initialize BigQuery client
project_id = "booming-octane-374400"  # replace with your project ID
bq_client = bigquery.Client(project=project_id)

# %%
from google.cloud import bigquery
import pandas as pd

# Set your GCP project
project_id = "booming-octane-374400"  # Replace with your project ID

# Initialize BigQuery client
bq_client = bigquery.Client(project=project_id)

# Read data from the local CSV file
df = pd.read_csv('/content/NYC_Crime_Data_Cleaned.csv')

# %% [markdown]
# Now that the data is in BigQuery, we can query it directly using SQL. Let's try to fetch the first few rows to verify the upload.
